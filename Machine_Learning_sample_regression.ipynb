# %%
#sklearn------------>ML task

# %%
#Leanier regeression

# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_samples=500,n_features=5)

# %%
x.shape
# Out:
# (500, 5)

# %%
y.shape
# Out:
# (500,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
import pandas as pd
input = pd.DataFrame(x,columns=['x1','x2','x3','x4',"x5"])
input
# Out:
#            x1        x2        x3        x4        x5
# 0   -0.469687 -0.417679  1.933819 -0.949709 -1.179547
# 1    0.977453  2.606282 -1.223543 -0.033457 -0.879829
# 2    2.187547 -1.092991  0.983523 -0.676368 -0.465608
# 3    0.975759 -0.435006 -0.998914 -0.292996 -1.372147
# 4    0.963493  0.247602 -1.824559 -0.013219  0.616550
# ..        ...       ...       ...       ...       ...
# 495 -0.299917 -0.636777 -0.972868  1.006728  0.325215
# 496  1.682705  0.991297 -0.641346  1.422267  0.372832
# 497  0.321119 -0.398123 -1.012787 -0.074898 -0.857828
# 498 -0.521811 -0.893439 -0.264363  0.313016  0.909577
# 499  2.096987  0.353637 -0.521456  0.723814 -1.338205
#
# [500 rows x 5 columns]

# %%
actual = pd.DataFrame(y,columns=["output"])
actual
# Out:
#          output
# 0    -84.395803
# 1    -71.859867
# 2    144.678972
# 3   -120.396016
# 4      4.164820
# ..          ...
# 495   23.401640
# 496  244.922611
# 497 -114.794341
# 498   38.044337
# 499   91.740745
#
# [500 rows x 1 columns]

# %%
#univariate task

# %%
inp = input.iloc[:,0]      #x1 feature
inp
# Out:
# 0     -0.469687
# 1      0.977453
# 2      2.187547
# 3      0.975759
# 4      0.963493
#          ...
# 495   -0.299917
# 496    1.682705
# 497    0.321119
# 498   -0.521811
# 499    2.096987
# Name: x1, Length: 500, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(input.iloc[:,0],actual,c='r')
plt.xlabel("x1")
plt.ylabel("actual")
# Out:
# Text(0, 0.5, 'actual')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_test,y_train=train_test_split(inp,actual,test_size=0.3,random_state=4)
x_train
# Out:
# 332    1.511887
# 282   -1.318281
# 153    0.701219
# 379    0.053959
# 413    0.713847
#          ...
# 385    0.369547
# 197    1.759519
# 439   -0.859080
# 174    0.038707
# 122   -1.845518
# Name: x1, Length: 350, dtype: float64

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=10)

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
from sklearn.datasets import load_diabetes
dataset = load_diabetes()

# %%
dir(dataset)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'data_module',
#  'feature_names',
#  'frame',
#  'target',
#  'target_filename']

# %%
import pandas as pd
x = pd.DataFrame(dataset.data,columns = dataset.feature_names)
x
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
y = pd.DataFrame(dataset.target,columns = ["Actual"])
y
# Out:
#      Actual
# 0     151.0
# 1      75.0
# 2     141.0
# 3     206.0
# 4     135.0
# ..      ...
# 437   178.0
# 438   104.0
# 439   132.0
# 440   220.0
# 441    57.0
#
# [442 rows x 1 columns]

# %%
y.head()
# Out:
#    Actual
# 0   151.0
# 1    75.0
# 2   141.0
# 3   206.0
# 4   135.0

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state =1)

# %%
model = LinearRegression
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-e0040b54f7f3> in <module>
#       1 model = LinearRegression
# ----> 2 model.fit(x_train,y_train)
#       3
#
# TypeError: fit() missing 1 required positional argument: 'y'
